# %% [markdown]
# # Титульный лист
# <a name = 'Титульный_лист'>

# %% [markdown]
# <font face="times new roman" size="3" color="black">
# <center> МИНИСТЕРСТВО ЦИФРОВОГО РАЗВИТИЯ, СВЯЗИ И МАССОВЫХ КОММУНИКАЦИЙ РОССИЙСКОЙ ФЕДЕРАЦИИ </center>
# <center>Ордена Трудового Красного Знамени федеральное государственное бюджетное образовательное учреждение высшего образования </center>
# <center> <strong> «Московский технический университет связи и информатики» </strong> </center>
#
#   <hr>
# <center> Кафедра «Телевидения и звукового вещания им. С.И. Катаева (ТиЗВ)» </center>
# <br>
# <center> <font face="times new roman" size="3" color="black"> Отчет по лабораторной работе № 12 </center>
# <center>по дисциплине </center>
# <center><b>«Информационные технологии и программирование»</b></center>
# <center>на тему</center>
# <center><b>«Система контроля»</b> </center>
#
# </font>
#
#   <br><br><br><br><br>
#   <p  align="right"> <font face="times new roman" size="3" color="black"> Выполнил: студент группы </p>
#   <p  align="right"> <font face="times new roman" size="3" color="black">       БИК2304 </p>
#   <p  align="right"> <font face="times new roman" size="3" color="black"> Артюхова Дарья Сергеевна</p>
#   <p  align="right"> <font face="times new roman" size="3" color="black"> Проверил:</p>
#   <p  align="right"> <font face="times new roman" size="3" color="black"> Ассистент кафедры ТиЗВ Кудряшов Всеволод Владимирович </p>
#   <br>
#   <br>
#
#   <p  align="center"> <font face="times new roman" size="2" color="black"> Москва, 2023 г. </p>
#
#   <hr>

# %% [markdown]
# > ## Содержание

# %% [markdown]
# [1. Титульный лист](#Титульный_лист)
#
# <a href = '#Постановка_задач'>2. Постановка задач </a>

# %% [markdown]
# # Постановка задач
# <a name = 'Постановка_задач'>

# %% [markdown]
# > ## Задание
# >
# > Установить GIT.
# >
# > Создать локальный репозиторий.
# >
# > Создать файл отчета по выполнению практической работы и поместить его в репозиторий
# >
# > Зафиксируйте в отчете все проделанные шаги и создайте версию отчета в GIT
# Создайте ветку отчета в GIT, добавьте описания шагов в отчет и создайте версию отчета в новой ветке.
# >
# > Слейте последнее изменение отчета в основную ветку.
# >
# > Регистрируемся на github (или используем уже существующий аккаунт), создаем проект «homework IIT», залете содержимое из локального репозитория в проект на githab.
# >
# > Разместить на github ранее созданный статический сайт.

# %% [markdown]
# ##Цель работы

# %% [markdown]
# Репозиторий на github

# %% [markdown]
# Задачи работы
#
# 1. Установить GIT.
# 2. Создать локальный репозиторий.
# 3. Создать файл отчета по выполнению практической работы и поместить его в репозиторий
# 4. Зафиксируйте в отчете все проделанные шаги и создайте версию отчета в GIT
# 5. Создайте ветку отчета в GIT, добавьте описания шагов в отчет и создайте версию отчета в новой ветке.
# 6. Слейте последнее изменение отчета в основную ветку.
# 7. Регистрируемся на github (или используем уже существующий аккаунт), создаем проект «homework IIT», залете содержимое из локального репозитория в проект на githab.
# 8. Разместить на github ранее созданный статический сайт.

# %% [markdown]
# ## Расчет входных данных

# %% [markdown]
# # Ход работы

# %% [markdown]
# 1. Решение задачи 1, установленный GIT.

# %% [markdown]
# 2. Решение задачи 2, создать локальный репозиторий.
#
# Реализация:
#
# ![git_2.PNG](data:image/png;base64,...)

# %% [markdown]
# 3. Решение задачи 3, создать файл отчета по выполнению практической работы и поместить его в репозиторий.
#
# Реализация:
#
# ![git_3.PNG](attachment:git_3.PNG)

# %% [markdown]
# 4. Решение задачи 4, зафиксировать в отчете все проделанные шаги и создать версию отчета в GIT.
#
# Реализация:
#
# ![gitttttt.PNG](attachment:gitttttt.PNG)

# %% [markdown]
# 5. Решение задачи 5, создайте ветку отчета в GIT, добавьте описания шагов в отчет и создайте версию отчета в новой ветке.
#
# Реализация:
#
# ![git_4.PNG](attachment:git_4.PNG)

# %% [markdown]
# 6. Решение задачи 6, Слейте последнее изменение отчета в основную ветку.
#
# Реализация:
#
# ![git_5.PNG](attachment:git_5.PNG)

# %% [markdown]
# 7. Решение задачи 7, регистрируемся на github (или используем уже существующий аккаунт), создаем проект «homework IIT», залете содержимое из локального репозитория в проект на githab.

# %% [markdown]
# # Результат выполнения работы
